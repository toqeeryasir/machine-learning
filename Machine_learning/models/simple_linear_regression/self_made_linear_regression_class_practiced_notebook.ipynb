# %% [markdown]
# # self_made Linear Regression class results

# %%
class ToqeersLinearRegression:
    
    def __init__(self):
        self.m = None
        self.b = None


    def fit(self, x_train, y_train):

        x_train = x_train.values
        y_train = y_train.values
        
        numerator = 0
        denominator = 0

        for i in range(x_train.shape[0]):
            numerator = numerator + ((x_train[i] - x_train.mean()) * (y_train[i] - y_train.mean()))
            denominator = denominator + ((x_train[i] - x_train.mean()) * (x_train[i] - x_train.mean()))

        self.m = numerator / denominator
        self.b = y_train.mean() - (self.m * x_train.mean())

    def predict(self, x_test):
        return (self.m * x_test + self.b)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df.drop(columns=['package'])
y = df['package']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state= None)

# %%
lr = ToqeersLinearRegression()

# %%
lr.fit(x_train, y_train)

# %%
prediction_resut = lr.predict(x_test.values[-2])

# %%
print(f'Predicted package of the given cgpa is: {prediction_resut}')
# Out:
# Predicted package of the given cgpa is: [3.54899792]

# %%
print(lr.m)
print(lr.b)
# Out:
# [0.57679812]
# [-1.07115499]

# %% [markdown]
# # sklearn built_in Linear Regression class results

# %%
from sklearn.linear_model import LinearRegression

# %%
lrr = LinearRegression()

# %%
lrr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lrr.coef_
# Out:
# array([0.57679812])

# %%
lrr.intercept_
# Out:
# -1.0711549865015275

# %%
lrr.predict(x_test)[-2]
# Out:
# 3.5489979168602845
